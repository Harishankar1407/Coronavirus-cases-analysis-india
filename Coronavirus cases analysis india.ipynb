# %%
# %matplotlib notebook

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
df=pd.read_excel(r'C:\Users\Asus\Downloads\Book 1.xlsx')

# %%
df
# Out:
#          State  Male(%)  Female(%)
# 0  Maharashtra       62         62
# 1   Tamil Nadu       68         68
# 2    Telangana       66         66
# 3    Karnataka       64         64
# 4        Bihar       58         58
# 5       Odisha       64         64
# 6    Jharkhand       75         75

# %%
df['Female(%)']=df['Female(%)'].replace([62,68,66,64,58,64,75],[38,32,33,36,42,36,25])

# %%
df
# Out:
#          State  Male(%)  Female(%)
# 0  Maharashtra       62         38
# 1   Tamil Nadu       68         32
# 2    Telangana       66         33
# 3    Karnataka       64         36
# 4        Bihar       58         42
# 5       Odisha       64         36
# 6    Jharkhand       75         25

# %%
df.set_index('State')
# Out:
#              Male(%)  Female(%)
# State
# Maharashtra       62         38
# Tamil Nadu        68         32
# Telangana         66         33
# Karnataka         64         36
# Bihar             58         42
# Odisha            64         36
# Jharkhand         75         25

# %%
x=df['Male(%)']
y=df['Female(%)']
z=df['State']
plt.figure()
plt.plot(z,x,'-o',z,y,'-o')
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">
# ...

# %%
plt.title('Coronavirus cases in states on the basis of gender')
plt.legend(['Male','Female'],frameon=False)

# %%
plt.xlabel('States')
plt.ylabel('Percentage')
# Out:
# Text(63.499993827607895, 0.5, 'Percentage')

# %%
x=plt.gca().xaxis
for item in x.get_ticklabels():
    item.set_rotation(45)

# %%
plt.subplots_adjust(bottom=0.25)

# %%
df.plot(kind="barh", width=0.8)
for i, (p, pr) in enumerate(zip(df['State'], df['Male(%)'])):
    plt.text(s=p, x=1, y=i, color="w", verticalalignment="center", size=10)
    plt.text(s=str(pr)+"%", x=pr-5, y=i, color="black",
             verticalalignment="center", horizontalalignment="left", size=16)
for i, (p, pr) in enumerate(zip(df['State'], df['Female(%)'])):
    plt.text(s=p, x=1, y=i, color="w", verticalalignment="center", size=10)
    plt.text(s=str(pr)+"%", x=pr-5, y=i, color="black",
             verticalalignment="center", horizontalalignment="left", size=16,clip_on=True)
plt.axis("off")

plt.legend(loc=4)
plt.title('Coronavirus cases in states of india categorized by gender')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
plt.subplots_adjust(bottom=0.25)
